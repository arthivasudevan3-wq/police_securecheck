# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
#read my file
pd.read_csv(r"D:\current documents\Downloads\traffic_stops - traffic_stops_with_vehicle_number.csv")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18632\544385259.py:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(r"D:\current documents\Downloads\traffic_stops - traffic_stops_with_vehicle_number.csv")
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# ...

# %%
secure_check=pd.read_csv(r"D:\current documents\Downloads\traffic_stops - traffic_stops_with_vehicle_number.csv")
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18632\1283503152.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   secure_check=pd.read_csv(r"D:\current documents\Downloads\traffic_stops - traffic_stops_with_vehicle_number.csv")

# %%
secure_check
# Out:
#         stop_date stop_time country_name driver_gender  driver_age_raw  \
# 0      2020-01-01   0:00:00       Canada             M              59
# 1      2020-01-01   0:01:00        India             M              35
# 2      2020-01-01   0:02:00          USA             M              26
# 3      2020-01-01   0:03:00       Canada             M              26
# 4      2020-01-01   0:04:00       Canada             M              62
# ...           ...       ...          ...           ...             ...
# 65533  2020-02-15  12:13:00        India             F              54
# 65534  2020-02-15  12:14:00       Canada             F              18
# 65535  2020-02-15  12:15:00          USA             M              27
# 65536  2020-02-15  12:16:00       Canada             F              49
# 65537  2020-02-15  12:17:00          USA             F              72
#
#        driver_age driver_race     violation_raw violation  search_conducted  \
# ...

# %%
secure_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  object
#  1   stop_time           65538 non-null  object
#  2   country_name        65538 non-null  object
#  3   driver_gender       65538 non-null  object
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  object
#  7   violation_raw       65538 non-null  object
#  8   violation           65538 non-null  object
#  9   search_conducted    65538 non-null  bool
#  10  search_type         43818 non-null  object
#  11  stop_outcome        65538 non-null  object
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  object
#  14  drugs_related_stop  65538 non-null  bool
# ...

# %%
secure_check.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# country_name              0
# driver_gender             0
# driver_age_raw            0
# driver_age                0
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           21720
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# vehicle_number            0
# dtype: int64

# %%
#fill my nan value
secure_check.fillna({'search_type':'unknown'},inplace=True)

# %%
secure_check.isnull().sum()
# Out:
# stop_date             0
# stop_time             0
# country_name          0
# driver_gender         0
# driver_age_raw        0
# driver_age            0
# driver_race           0
# violation_raw         0
# violation             0
# search_conducted      0
# search_type           0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# drugs_related_stop    0
# vehicle_number        0
# dtype: int64

# %%
#convert my object data type into datetime
secure_check['stop_date']=pd.to_datetime(secure_check['stop_date'])

# %%
secure_check['stop_time']=pd.to_datetime(secure_check['stop_time'])
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18632\3645648568.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   secure_check['stop_time']=pd.to_datetime(secure_check['stop_time'])

# %%
secure_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65538 entries, 0 to 65537
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           65538 non-null  datetime64[ns]
#  1   stop_time           65538 non-null  datetime64[ns]
#  2   country_name        65538 non-null  object
#  3   driver_gender       65538 non-null  object
#  4   driver_age_raw      65538 non-null  int64
#  5   driver_age          65538 non-null  int64
#  6   driver_race         65538 non-null  object
#  7   violation_raw       65538 non-null  object
#  8   violation           65538 non-null  object
#  9   search_conducted    65538 non-null  bool
#  10  search_type         65538 non-null  object
#  11  stop_outcome        65538 non-null  object
#  12  is_arrested         65538 non-null  bool
#  13  stop_duration       65538 non-null  object
#  14  drugs_related_stop  65538 non-null  bool
# ...

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#connect mydatabase into sql
import pymysql
mydb=pymysql.connect(
    host="localhost",
    user="root",
    password="Rudra",
    #auth_plugin="mysql_native_password"
)

mycursor=mydb.cursor()
#mycursor.execute("CREATE DATABASE policecheck")

# %%
#mycursor.execute("CREATE DATABASE policecheck")

# %%
mycursor.execute("use policecheck;")
# Out:
# 0

# %%
mycursor.execute("""CREATE TABLE IF NOT EXISTS Police_postlog(
                 id INT AUTO_INCREMENT PRIMARY KEY,
                 Stop_date DATE,
                 stop_time TIMESTAMP,
                 country_name VARCHAR(50),
                 driver_gender VARCHAR(10),
                 driver_age	INT,
                 violation	VARCHAR(50),
                 search_conducted BOOLEAN,
                 search_type VARCHAR(50),
                 stop_outcome VARCHAR(50),
                 is_arrested	BOOLEAN,
                 stop_duration VARCHAR(50),
                 drugs_related_stop BOOLEAN,
                 vehicle_number VARCHAR(50)
                 )""")
mydb.commit()
print("Table 'police_postlog' created successfully in MySQL!")
# Out:
# Table 'police_postlog' created successfully in MySQL!

# %%
secure_check.columns
# Out:
# Index(['stop_date', 'stop_time', 'country_name', 'driver_gender',
#        'driver_age_raw', 'driver_age', 'driver_race', 'violation_raw',
#        'violation', 'search_conducted', 'search_type', 'stop_outcome',
#        'is_arrested', 'stop_duration', 'drugs_related_stop', 'vehicle_number'],
#       dtype='object')

# %%
mycursor.execute("ALTER TABLE police_postlog ADD COLUMN  driver_age_raw	INT ")
# Out:
# 0

# %%
mycursor.execute("ALTER TABLE police_postlog ADD COLUMN driver_race VARCHAR(50)")
# Out:
# 0

# %%
mycursor.execute("ALTER TABLE police_postlog ADD COLUMN violation_raw VARCHAR(50)")
# Out:
# 0

# %%
#insert my data in table
data_list = secure_check.values.tolist()
query = """
    INSERT INTO police_postlog (stop_date , stop_time,country_name , driver_gender , driver_age_raw,  driver_age,  driver_race  ,violation_raw  ,violation ,  search_conducted , search_type  ,stop_outcome,
is_arrested ,stop_duration ,drugs_related_stop  ,vehicle_number)      
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s ,%s ,%s ,%s ,%s ,%s, %s);
"""
mycursor.executemany(query, data_list)
mydb.commit()
print("Data inserted using to_list()")
# Out:
# Data inserted using to_list()
